# %%
import numpy as np
import pandas as pd
import random 
from pprint import pprint

PATH = '../data/house_price_dataset.csv'

# %%
result = pd.read_csv(PATH)
result.set_index(np.array( [i for i in range(1000)] ))
result
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
shuffle_index = np.random.permutation( result.index )
result = result.set_index(shuffle_index)
result
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 277            1360             2              1        1981  0.599637
# 286            4272             3              3        2016  4.753014
# 901            3592             1              2        2016  3.634823
# 61              966             1              2        1977  2.730667
# 384            4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 858            3261             4              1        1978  2.165110
# 234            3179             1              2        1999  2.977123
# 813            2606             4              2        1962  4.055067
# 174            4723             5              2        1950  1.930921
# 581            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 277            0                     5  2.623829e+05
# ...
